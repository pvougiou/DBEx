# %%
import numpy as np
import re
import pandas as pd
pd.set_option('display.max_colwidth', -1)
import cPickle as pickle
wikipedia_pickle = '../Data/WikiAstronauts/WikiAstronauts-DBpedia.p'
medline_pickle = '../Data/MedlinePlus/MedlinePlus-SemRep.p'

# %%
wiki_list = pickle.load( open( wikipedia_pickle, "rb" ) )
medline_list = pickle.load( open( medline_pickle, "rb" ) )

# %%
def clean_annotations(string):
    formal = True
    annotations = re.findall(r'(\[\[[0-9a-zA-Z_.,\-\(\)\%\'\|\ ]+\]\])', string)
    if len(annotations) > 0:
        for annotation in annotations:
            if formal:
                replacement = re.findall(r'\|([0-9a-zA-Z_.,\-\(\)\%\']+)\]\]', annotation)
            else:
                replacement = re.findall(r'\[\[([0-9a-zA-Z_.,\-\(\)\%\'\ ]+)\|', annotation)
            string = string.replace(annotation, replacement[0])
        clean_annotations(string)
    return string

# %%
namespaces = ['(http\:\/\/dbpedia\.org/\w+\/)', 'http\:\/\/www\.w3\.org\/1999\/02\/22\-rdf\-syntax\-ns\#', 'http\:\/\/www\.w3\.org\/2000\/01\/rdf\-schema\#']
def clean_namespace(triples):
    for j in range(0, len(triples)):
        for namespace in namespaces:
            triples[j] = re.sub(re.compile(namespace, re.DOTALL), '', triples[j])\
              .replace('\t', '').replace('\n', '') 
    return triples
print clean_namespace(wiki_list[0]['triples'])
# Out:
# ['Soyuz_TM-6 crewLaunching Abdul_Ahad_Mohmand']

# %%
def highlight(triples):
    for j in range(0, len(triples)):
        triples[j] = triples[j].split()
        triples[j][0] = '<b><font color="blue">' + triples[j][1] + '</font></b>'
        triples[j][1] = '<b><font color="red">' + triples[j][1] + '</font></b>'
        triples[j][-1] = '<b><font color="blue">' + triples[j][1] + '</font></b>'
        triples[j] = ' '.join(triples[j])
    return triples
print highlight((wiki_list[0]['triples']))[0]
# Out:
# <b><font color="blue">crewLaunching</font></b> <b><font color="red">crewLaunching</font></b> <b><font color="blue"><b><font color="red">crewLaunching</font></b></font></b>

# %%
def clean_annotations(original, triples, unlinked_entities):
    #print('Original')
    #print original, triples
    annotations = re.findall(r'(\[\[[0-9a-zA-Z_.,\-\(\)\%\'\|\ ]+\]\])', original)
    if len(annotations) > 0:
        for annotation in annotations:
            formal_part = re.findall(r'\|([0-9a-zA-Z_.,\-\(\)\%\']+)\]\]', annotation)[0]
            informal_part = re.findall(r'\[\[([0-9a-zA-Z_.,\-\(\)\%\'\ ]+)\|', annotation)[0]
            original = original.replace(annotation, '<b><font color="blue">' + informal_part + '</font></b>')
            #print simplification
            #print formal_part
            for i in range(0, len(triples)):
                triples[i] = triples[i].split()
                if formal_part == triples[i][0]:
                    triples[i][0] = informal_part
                    if formal_part in unlinked_entities:
                        unlinked_entities.remove(formal_part)
                if formal_part == triples[i][-1]:
                    triples[i][-1] = informal_part
                    if formal_part in unlinked_entities:
                        unlinked_entities.remove(formal_part)
                triples[i] = ' '.join(triples[i])
                """
                if formal_part in triples[i]:
                    #namespace = re.findall(r'([0-9a-zA-Z_.,\-\(\)\%\'\:\/])+{}'.format(re.escape(formal_part)), triples[i])[0]
                    namespace = re.findall(r'({})'.format(re.escape(formal_part)), triples[i])[0]
                    triples[i] = triples[i].replace(namespace, informal_part)
                """
        clean_annotations(original, triples, unlinked_entities)
    return original, triples, unlinked_entities

# %%
def exclude(triples, unlinked_entities):
    for entity in unlinked_entities:
        for i in range(len(triples) - 1, -1, -1):
            triples[i] = triples[i].split()
            if triples[i][0] == entity or triples[i][-1] == entity:
                triples[i] = ' '.join(triples[i])
                print('Removing triple-fact: %s ...' % (triples[i]))
                triples.pop(i)
            else: triples[i] = ' '.join(triples[i])
    return triples

def setup_experiment(list):
    num_sentences = 20
    incl_sentences = []
    while len(incl_sentences) < num_sentences:
        sentence = np.random.randint(0, len(list))
        entities = []
        init_triples = highlight(clean_namespace(list[sentence]['triples']))
        for i in range(0, len(init_triples)):
                init_triples[i] = init_triples[i].split()
                if init_triples[i][0] not in entities: entities.append(init_triples[i][0])
                if init_triples[i][-1] not in entities: entities.append(init_triples[i][-1])
                init_triples[i] = ' '.join(init_triples[i])
        annotated_sentence, triples, unlinked_entities = clean_annotations(list[sentence]['annotated_sentence'].replace('\t', '').replace('\n', ''), \
                                              init_triples, entities)
        triples = exclude(triples, unlinked_entities)
        if len(triples) > 0:
            incl_sentences.append({'Original Sentence': annotated_sentence})

            incl_sentences[len(incl_sentences) - 1]['Triple-Fact 1'] = triples[0]         
            for j in range(1, len(list[sentence]['triples'])):
                incl_sentences[len(incl_sentences) - 1][('Triple-Fact %d' % (j + 1))] = triples[j]
            list.pop(sentence)
    return incl_sentences

# %%
#output_df = pd.DataFrame(setup_experiment(wiki_list + medline_list))
output_df = pd.DataFrame(setup_experiment(wiki_list))
output_df.to_csv('../Data/Shorten-Sentence.csv', index=False)
# Out:
# Removing triple-fact: <b><font color="blue">shipNamesake</font></b> <b><font color="red">shipNamesake</font></b> <b><font color="blue"><b><font color="red">shipNamesake</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">shipNamesake</font></b> <b><font color="red">shipNamesake</font></b> <b><font color="blue"><b><font color="red">shipNamesake</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">location</font></b> <b><font color="red">location</font></b> <b><font color="blue"><b><font color="red">location</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">genre</font></b> <b><font color="red">genre</font></b> <b><font color="blue"><b><font color="red">genre</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">rank</font></b> <b><font color="red">rank</font></b> <b><font color="blue"><b><font color="red">rank</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">nationality</font></b> <b><font color="red">nationality</font></b> <b><font color="blue"><b><font color="red">nationality</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">mission</font></b> <b><font color="red">mission</font></b> <b><font color="blue"><b><font color="red">mission</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">crewMembers</font></b> <b><font color="red">crewMembers</font></b> <b><font color="blue"><b><font color="red">crewMembers</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">crew4Up</font></b> <b><font color="red">crew4Up</font></b> <b><font color="blue"><b><font color="red">crew4Up</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">mission</font></b> <b><font color="red">mission</font></b> <b><font color="blue"><b><font color="red">mission</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">state</font></b> <b><font color="red">state</font></b> <b><font color="blue"><b><font color="red">state</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">color="blue">crewLaunching</font></b></font></b> <b><font color="red">color="blue">crewLaunching</font></b></font></b> <b><font color="red">crewLaunching</font></b> <b><font color="blue"><b><font <b><font color="blue"><b><font color="red">color="blue">crewLaunching</font></b></font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">birthPlace</font></b> <b><font color="red">birthPlace</font></b> <b><font color="blue"><b><font color="red">birthPlace</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">location</font></b> <b><font color="red">location</font></b> <b><font color="blue"><b><font color="red">location</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">crew2Up</font></b> <b><font color="red">crew2Up</font></b> <b><font color="blue"><b><font color="red">crew2Up</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">crewMembers</font></b> <b><font color="red">crewMembers</font></b> <b><font color="blue"><b><font color="red">crewMembers</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">mission</font></b> <b><font color="red">mission</font></b> <b><font color="blue"><b><font color="red">mission</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue
font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">education</font></b> <b><font color="red">education</font></b> <b><font color="blue"><b><font color="red">education</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">rank</font></b> <b><font color="red">rank</font></b> <b><font color="blue"><b><font color="red">rank</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">nationality</font></b> <b><font color="red">nationality</font></b> <b><font color="blue"><b><font color="red">nationality</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">occupation</font></b> <b><font color="red">occupation</font></b> <b><font color="blue"><b><font color="red">occupation</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">occupation</font></b> <b><font color="red">occupation</font></b> <b><font color="blue"><b><font color="red">occupation</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">militaryBranch</font></b> <b><font color="red">militaryBranch</font></b> <b><font color="blue"><b><font color="red">militaryBranch</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">crewMembers</font></b> <b><font color="red">crewMembers</font></b> <b><font color="blue"><b><font color="red">crewMembers</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">crew2Up</font></b> <b><font color="red">crew2Up</font></b> <b><font color="blue"><b><font color="red">crew2Up</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">mission</font></b> <b><font color="red">mission</font></b> <b><font color="blue"><b><font color="red">mission</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">rank</font></b> <b><font color="red">rank</font></b> <b><font color="blue"><b><font color="red">rank</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">seeAlso</font></b> <b><font color="red">seeAlso</font></b> <b><font color="blue"><b><font color="red">seeAlso</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">seeAlso</font></b> <b><font color="red">seeAlso</font></b> <b><font color="blue"><b><font color="red">seeAlso</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">starring</font></b> <b><font color="red">starring</font></b> <b><font color="blue"><b><font color="red">starring</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">location</font></b> <b><font color="red">location</font></b> <b><font color="blue"><b><font color="red">location</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">occupation</font></b> <b><font color="red">occupation</font></b> <b><font color="blue"><b><font color="red">occupation</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">birthPlace</font></b> <b><font color="red">birthPlace</font></b> <b><font color="blue"><b><font color="red">birthPlace</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">rank</font></b> <b><font color="red">rank</font></b> <b><font color="blue"><b><font color="red">rank</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">type</font></b> <b><font color="red">type</font></b> <b><font color="blue"><b><font color="red">type</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">lastFlight</font></b> <b><font color="red">lastFlight</font></b> <b><font color="blue"><b><font color="red">lastFlight</font></b></font></b> ...
# Removing triple-fact: <b><font color="blue">birthPlace</font></b> <b><font color="red">birthPlace</font></b> <b><font color="blue"><b><font color="red">birthPlace</font></b></font></b> ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-df7dffb0b9ba> in <module>()
#       1 #output_df = pd.DataFrame(setup_experiment(wiki_list + medline_list))
# ----> 2 output_df = pd.DataFrame(setup_experiment(wiki_list))
#       3 output_df.to_csv('../Data/Shorten-Sentence.csv', index=False)
#
# <ipython-input-7-a77012ec3090> in setup_experiment(list)
#      22                 if init_triples[i][-1] not in entities: entities.append(init_triples[i][-1])
#      23                 init_triples[i] = ' '.join(init_triples[i])
# ---> 24         annotated_sentence, triples, unlinked_entities = clean_annotations(list[sentence]['annotated_sentence'].replace('\t', '').replace('\n', ''),                                               init_triples, entities)
#      25         triples = exclude(triples, unlinked_entities)
#      26         if len(triples) > 0:
#
# <ipython-input-6-296688588fc9> in clean_annotations(original, triples, unlinked_entities)
#       6         for annotation in annotations:
#       7             formal_part = re.findall(r'\|([0-9a-zA-Z_.,\-\(\)\%\']+)\]\]', annotation)[0]
# ----> 8             informal_part = re.findall(r'\[\[([0-9a-zA-Z_.,\-\(\)\%\'\ ]+)\|', annotation)[0]
#       9             original = original.replace(annotation, '<b><font color="blue">' + informal_part + '</font></b>')
#      10             #print simplification
#
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/re.pyc in findall(pattern, string, flags)
#     179
#     180     Empty matches are included in the result."""
# --> 181     return _compile(pattern, flags).findall(string)
#     182
#     183 if sys.hexversion >= 0x02020000:
#
# KeyboardInterrupt:
